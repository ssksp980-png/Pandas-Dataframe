# %% [markdown]
# **Pandas Dataframe**

# %% [markdown]
# 1  . import pandas as pd
#      data = {
#       'peoduct' : ['product A' , 'product B ' , 'product C' , 'product D' ,
#       'product E'],
#       'Region' : ['North', 'South', 'East' , 'West' , 'Central'],
#       'Sales' : [1200, 850 ,1500 , 950 , 1300],
#       'Quantity': [50 ,30 ,60 ,40 ,55 ]
#      }
#      df = pd.Dataframe (data)
#      print(df)
#
# 2  . df = pd.read_csv("Retail_Dataset.csv")
#    . print(df.head())
#    . print(df.tail())
#    . print(df.info())
#    . print(df.shape)
#
#
# 3  . df[['Product','Region','Sales']]
#
# 4  . df.loc[10]
#    . df.loc[20, 'Sales']
#
# 5  . df.iloc[0:6 , 0:4 ]
#    . df.iloc[2 , 2]
#
# 6  . df.head(10)
#    . df.iloc[14:25]
#
# 7  . df[df['Region'] =='East']
#    . df[df['Sales'] > 1500 ]
#
# 8  . df(df['Region'] =='West') and (df['Sales'] > 1200]
#
# 9  . Summary = df.describe()
#      mean_Sales = summary.loc['mean','Sales']
#      max_quantity = df['Quantity'].max()
#      min_Sales = summary.loc['min','Sales']
#
# 10  . total_sales = df.['Sales'].sum()
#       avg_sales = df.['sales'].mean()
#       max_sales = df.['sales'].max()
#       min_sales = df.['sales'].min()
